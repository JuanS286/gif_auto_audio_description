# %%
# !pip install pandas
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
import pandas as pd
import os

# Load the TSV file without header
#df = pd.read_csv('categorization_subject.csv', delimiter='\t', header=None)
#current_directory = os.getcwd()

file_path = 'gif_categorization_VF.csv'
df = pd.read_csv(file_path, delimiter=',')

# Preview the first few rows
df.head()
# Out:
#       ID                                            gif_url  \
# 0   3743  https://33.media.tumblr.com/0c3fbafcc0ef88b044...
# 1  69871  https://38.media.tumblr.com/537399ec3dfeedda45...
# 2   1468  https://31.media.tumblr.com/2358c8a2f965f0cc02...
# 3  52688  https://33.media.tumblr.com/064c8ee68875eb2869...
# 4  30531  https://31.media.tumblr.com/tumblr_maxeaje75L1...
#
#                                          description  Frame Count category
# 0  1 man holding a wallet, while the other man ta...         21.0   Humans
# 1    2 girls create a heart symbol with their hands.         53.0   Humans
# 2      2 girls hugging and swaying from side to side         48.0   Humans
# 3               2 girls move their hands as a dance.          NaN   Humans
# 4    2 men are shown sitting on a couch and talking.        141.0   Humans

# %%
import re

# Function to remove punctuation and special characters
def clean_text(text):
    cleaned_text = re.sub(r'[^\w\s]', '', text)  # Removes everything except words and spaces
    return cleaned_text

# Apply the cleaning function to the 'Description' column
df['description'] = df['description'].apply(clean_text)

# Preview the cleaned data
df.head()
# Out:
#       ID                                            gif_url  \
# 0   3743  https://33.media.tumblr.com/0c3fbafcc0ef88b044...
# 1  69871  https://38.media.tumblr.com/537399ec3dfeedda45...
# 2   1468  https://31.media.tumblr.com/2358c8a2f965f0cc02...
# 3  52688  https://33.media.tumblr.com/064c8ee68875eb2869...
# 4  30531  https://31.media.tumblr.com/tumblr_maxeaje75L1...
#
#                                          description  Frame Count category
# 0  1 man holding a wallet while the other man tak...         21.0   Humans
# 1     2 girls create a heart symbol with their hands         53.0   Humans
# 2      2 girls hugging and swaying from side to side         48.0   Humans
# 3                2 girls move their hands as a dance          NaN   Humans
# 4     2 men are shown sitting on a couch and talking        141.0   Humans

# %%
# Remove rows with missing or null descriptions
df.dropna(subset=['description'], inplace=True)

# Preview the cleaned data
df.head()
# Out:
#       ID                                            gif_url  \
# 0   3743  https://33.media.tumblr.com/0c3fbafcc0ef88b044...
# 1  69871  https://38.media.tumblr.com/537399ec3dfeedda45...
# 2   1468  https://31.media.tumblr.com/2358c8a2f965f0cc02...
# 3  52688  https://33.media.tumblr.com/064c8ee68875eb2869...
# 4  30531  https://31.media.tumblr.com/tumblr_maxeaje75L1...
#
#                                          description  Frame Count category
# 0  1 man holding a wallet while the other man tak...         21.0   Humans
# 1     2 girls create a heart symbol with their hands         53.0   Humans
# 2      2 girls hugging and swaying from side to side         48.0   Humans
# 3                2 girls move their hands as a dance          NaN   Humans
# 4     2 men are shown sitting on a couch and talking        141.0   Humans

# %%
# Remove extra spaces
df['description'] = df['description'].str.strip()

# Preview the result
df.head()
# Out:
#       ID                                            gif_url  \
# 0   3743  https://33.media.tumblr.com/0c3fbafcc0ef88b044...
# 1  69871  https://38.media.tumblr.com/537399ec3dfeedda45...
# 2   1468  https://31.media.tumblr.com/2358c8a2f965f0cc02...
# 3  52688  https://33.media.tumblr.com/064c8ee68875eb2869...
# 4  30531  https://31.media.tumblr.com/tumblr_maxeaje75L1...
#
#                                          description  Frame Count category
# 0  1 man holding a wallet while the other man tak...         21.0   Humans
# 1     2 girls create a heart symbol with their hands         53.0   Humans
# 2      2 girls hugging and swaying from side to side         48.0   Humans
# 3                2 girls move their hands as a dance          NaN   Humans
# 4     2 men are shown sitting on a couch and talking        141.0   Humans

# %%
#import re

# Function to extract subject and action from the description
#def extract_subject_action(description):
    # Split description into words
    #words = description.split()

    # Simple heuristic to determine subject (first few words) and action (rest)
    # You may need to adjust this logic based on your data
    #sujeto = ''
    #action = ''

    # Use regex to find the subject (could be one or two words)
    # This is a basic heuristic and may not work for all cases
    #sujeto_pattern = r'^(a|an|the)?\s*(\w+)\s*(\w+)?'
    #match = re.match(sujeto_pattern, description)

    #if match:
        #sujeto = match.group().strip()  # Subject
        #action = description[len(sujeto):].strip()  # Remaining part as action

    #return pd.Series([sujeto, action])  # Return as a Series

# Apply the extraction function to create new columns
#df[['Subject', 'Action']] = df['Description_1'].apply(extract_subject_action)

# Preview the updated dataframe
#df.head()

# %%
# Display the first few rows of the updated dataframe
#print(df[['URL', 'Description', 'Category']].head(10))

# %%
# List of common connector words (stop words)
#connector_words = [
    #"and", "or", "but", "is", "are", "the", "a", "an", "to", "in",
    #"with", "for", "on", "at", "by", "of", "as", "that", "this",
    #"it", "so", "then", "than", "if", "while", "where", "when",
    #"who", "which", "what", "how", "because", "since", "after",
    #"before", "between", "during", "while", "along", "about", "like",
    #"not", "no", "yes"
#]

#def remove_connector_words(text):
    # Split the text into words
    #words = text.split()
    # Filter out the connector words and join them back into a string
    #filtered_text = ' '.join(word for word in words if word.lower() not in connector_words)
    #return filtered_text

# Apply the function to remove connector words from Subject and Action columns
#df['Subject'] = df['Subject'].apply(remove_connector_words)
#df['Action'] = df['Action'].apply(remove_connector_words)

# Preview the updated dataframe
#df.head()

# %%
# Display the first few rows of the updated dataframe
#print(df[['Image_URL', 'Description_1', 'Subject', 'Action']].head(10))

# %% [markdown]
# **Sentiment Analysis**

# %%
from textblob import TextBlob

# Define a function for sentiment analysis
def get_sentiment(text):
    blob = TextBlob(text)
    # Polarity ranges from -1 (negative) to 1 (positive)
    return blob.sentiment.polarity

# Apply the sentiment analysis function to the GIF descriptions
df['Sentiment'] = df['description'].apply(get_sentiment)

def get_sentiment_category(text):
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity

    if polarity > 0.05:
        return "Positive"
    elif polarity < -0.05:
        return "Negative"
    else:
        return "Neutral"

# Apply the sentiment analysis function to the GIF descriptions
df['Sentiment_Category'] = df['description'].apply(get_sentiment_category)

# Check the result
df[['description', 'Sentiment', 'Sentiment_Category']].head()
# Out:
#                                          description  Sentiment  \
# 0  1 man holding a wallet while the other man tak...     -0.125
# 1     2 girls create a heart symbol with their hands      0.000
# 2      2 girls hugging and swaying from side to side      0.000
# 3                2 girls move their hands as a dance      0.000
# 4     2 men are shown sitting on a couch and talking      0.000
#
#   Sentiment_Category
# 0           Negative
# 1            Neutral
# 2            Neutral
# 3            Neutral
# 4            Neutral

# %% [markdown]
# Polarity: Ranges from -1 (negative sentiment) to 1 (positive sentiment).
# For example, a description like "a man is smiling" might yield a positive sentiment, while "a cat is scared" might yield a negative sentiment.

# %% [markdown]
# A polarity of 0.0 means that the text is considered neutral. It does not express strong positive or negative emotions. For example, a neutral sentence might state a fact or provide information without showing any sentiment, such as:
#
# "The sky is blue."
# "The meeting is scheduled for tomorrow."

# %%
# Replace 'unknown' values with a more appropriate label or drop them
#df['Subject'] = df['Subject'].replace('unknown', 'Unspecified')
#df['Action'] = df['Action'].replace('unknown', 'Unspecified')
#df.drop_duplicates(subset=['Description'], inplace=True)

# Display the first few rows of the updated dataframe
#print(df[['URL', 'Description_1', 'Subject', 'Action', 'Sentiment']].head(10))

# %% [markdown]
# **Separating the Actions from the Description**

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

# Function to extract the first two present or past tense verbs excluding 'is' and 'are'
def extract_verbs(description):
    words = nltk.word_tokenize(description)  # Tokenize the sentence
    pos_tags = nltk.pos_tag(words)  # POS tagging

    verbs = []
    for i, (word, pos) in enumerate(pos_tags):
        # Check for present tense (VB, VBP, VBZ), past tense (VBD), or present continuous (VBG)
        if (pos in ['VB', 'VBP', 'VBZ', 'VBD'] and word.lower() not in ['is', 'are']):
            verbs.append(word)
        elif pos == 'VBG':  # Identify gerund forms
            # Check for the auxiliary verb (am, is) in the previous tokens
            if i > 0 and pos_tags[i - 1][0].lower() in ['am', 'is']:
                verbs.append(word)
            # Allow gerunds that may not be immediately preceded by an auxiliary
            elif len(verbs) < 2:  # Allow adding if we don't have two actions yet
                verbs.append(word)

        # Include specific verbs like standing, turning, jumping, etc.
        if word.lower() in ['standing', 'turning', 'jumping'] and word.lower() not in ['is', 'are']:
            verbs.append(word)

        # Stop after extracting the first two verbs
        if len(verbs) == 2:
            break

    return verbs

# Apply the verb extraction function to the Description column
df['Actions'] = df['description'].apply(extract_verbs)

# Create the Action_1 and Action_2 columns
df['Action_1'] = df['Actions'].apply(lambda x: x[0] if len(x) > 0 else None)
df['Action_2'] = df['Actions'].apply(lambda x: x[1] if len(x) > 1 else None)

# Keep only the necessary columns: URL, Description, Category, Action_1, Action_2
df = df[['ID', 'gif_url', 'description', 'Frame Count', 'category', 'Sentiment', 'Sentiment_Category', 'Action_1', 'Action_2']]

# Display the resulting DataFrame
print(df)
# Out:
#           ID                                            gif_url  \
# 0       3743  https://33.media.tumblr.com/0c3fbafcc0ef88b044...
# 1      69871  https://38.media.tumblr.com/537399ec3dfeedda45...
# 2       1468  https://31.media.tumblr.com/2358c8a2f965f0cc02...
# 3      52688  https://33.media.tumblr.com/064c8ee68875eb2869...
# 4      30531  https://31.media.tumblr.com/tumblr_maxeaje75L1...
# ...      ...                                                ...
# 89730  54158  https://33.media.tumblr.com/6575cebd0e198b30df...
# 89731   4586  https://33.media.tumblr.com/96626eee35f2a4be40...
# 89732   3361  https://33.media.tumblr.com/ad478e69a97bb1988f...
# 89733  30137  https://38.media.tumblr.com/b84df984242995da73...
# 89734  38632  https://38.media.tumblr.com/5de4a17ae7e370f46e...
#
#                                              description  Frame Count  \
# 0      1 man holding a wallet while the other man tak...         21.0
# ...

# %% [markdown]
# The NLTK (Natural Language Toolkit) library is a powerful suite of tools for working with human language data (text). It provides libraries for various tasks like tokenization, part-of-speech (POS) tagging, and more.

# %%
df[['description', 'Action_1', 'Action_2']].head(10)
# Out:
#                                          description Action_1 Action_2
# 0  1 man holding a wallet while the other man tak...  holding    takes
# 1     2 girls create a heart symbol with their hands   create     None
# 2      2 girls hugging and swaying from side to side  hugging  swaying
# 3                2 girls move their hands as a dance     move     None
# 4     2 men are shown sitting on a couch and talking  sitting  talking
# 5  2 motorcyclists turning the corner on a desert...  turning  turning
# 6  2 people are sitting on a coach talking and la...  sitting  talking
# 7     2 people are smoking and blowing the smoke out  smoking  blowing
# 8  2 person rip off their pant but they have anot...      rip     have
# 9            2 white dogs sit in a box looking tired  looking    tired

# %%
# Save the cleaned data to a CSV file
df.to_csv('Dashboard_dataset_Milestones1&2.csv', index=False)

# %%
from google.colab import files

# Download the saved CSV file
files.download('Dashboard_dataset_Milestones1&2.csv')
