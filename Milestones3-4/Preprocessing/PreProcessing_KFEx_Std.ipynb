# %% [markdown]
# # **JSON generator**

# %%
import os
import json
import imageio
import cv2
import numpy as np
from io import BytesIO
from skimage.metrics import structural_similarity as ssim
from google.cloud import storage
from google.colab import auth
import tempfile

auth.authenticate_user()

# Set up Google Cloud Storage client
storage_client = storage.Client()
bucket_name = 'gif-bucket-1000'
bucket = storage_client.bucket(bucket_name)

def resize_and_normalize_frame(frame, target_size=(256, 256)):  # Changed target_size
    """Resize and normalize the frame while preserving aspect ratio."""
    original_height, original_width = frame.shape[:2]
    aspect_ratio = original_width / original_height

    if aspect_ratio > 1:  # Wider than tall
        new_width = target_size[0]
        new_height = int(target_size[0] / aspect_ratio)
    else:  # Taller than wide or square
        new_width = int(target_size[1] * aspect_ratio)
        new_height = target_size[1]

    resized_frame = cv2.resize(frame, (new_width, new_height))

    # Calculate padding
    delta_w = target_size[0] - new_width
    delta_h = target_size[1] - new_height
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Add padding to maintain the target size
    normalized_frame = cv2.copyMakeBorder(resized_frame, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    normalized_frame = normalized_frame.astype(np.float32) / 255.0

    return normalized_frame

def augment_frame(frame):
    """Apply random data augmentation to the frame."""
    if np.random.rand() < 0.5:
        frame = cv2.flip(frame, 1)  # Horizontal flip
    if np.random.rand() < 0.5:
        rows, cols = frame.shape[:2]
        rotation_angle = np.random.randint(-10, 10)
        M = cv2.getRotationMatrix2D((cols/2, rows/2), rotation_angle, 1)
        frame = cv2.warpAffine(frame, M, (cols, rows))
    return frame

def extract_key_frames(frames, ssim_threshold=0.95, min_scene_change=10, max_key_frames=25):  # Added max_key_frames
    """Extract key frames based on structural similarity."""
    key_frames = []
    prev_frame = None
    scene_change_counter = 0
    scene_changes = []  # Initialize scene_changes here

    for i, frame in enumerate(frames):
        if not isinstance(frame, np.ndarray):
            print(f"Frame {i}: Not a valid NumPy array.")
            continue

        if frame.size == 0 or len(frame.shape) != 3:
            print(f"Frame {i}: Empty or has invalid dimensions: {frame.shape if isinstance(frame, np.ndarray) else 'N/A'}")
            continue

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)

        if prev_frame is None:
            key_frames.append(frame)
            prev_frame = gray_frame
            continue

        similarity_score = ssim(prev_frame, gray_frame, data_range=1.0)

        if similarity_score < ssim_threshold:
            scene_change_counter += 1
            if scene_change_counter >= min_scene_change and len(key_frames) < max_key_frames:  # Check max_key_frames
                key_frames.append(frame)
                scene_changes.append(i)  # Add index to scene_changes
                scene_change_counter = 0
        else:
            scene_change_counter = 0

        prev_frame = gray_frame

    return key_frames, scene_changes  # Return scene_changes


def preprocess_gif(gif_file_name, gif_id):
    """Preprocesses a GIF from GCS, extracts key frames, and uploads them to the bucket."""
    try:
        gif_blob = bucket.blob(os.path.join('gifs', gif_file_name))
        gif_bytes = gif_blob.download_as_bytes()

        with imageio.get_reader(BytesIO(gif_bytes), 'gif') as reader:
            frame_count = reader.get_length()
            try:
                frame_rate = 1 / reader.get_meta_data()['duration']
            except (KeyError, AttributeError, ZeroDivisionError):
                frame_rate = 10

            processed_frames = []
            for frame in reader:
                if frame.shape[-1] == 4:
                    frame = cv2.cvtColor(frame, cv2.COLOR_RGBA2RGB)
                resized_frame = resize_and_normalize_frame(frame)
                augmented_frame = augment_frame(resized_frame)
                processed_frames.append(augmented_frame)

        key_frames, scene_changes = extract_key_frames(processed_frames)

        frame_paths = []
        for i, frame in enumerate(key_frames):
            # Construct the path for the frame in the bucket
            frame_path = os.path.join('gif_frames_std', str(gif_id), f'frame_{i}.png')

            # Create a new blob and upload the frame
            frame_blob = bucket.blob(frame_path)
            _, temp_local_filename = tempfile.mkstemp()
            frame = (frame * 255).astype(np.uint8)
            imageio.imwrite(temp_local_filename, frame, format='PNG')
            frame_blob.upload_from_filename(temp_local_filename)
            os.remove(temp_local_filename)

            frame_paths.append(frame_path)  # Store the GCS path

        gif_data = {
            'gif_id': gif_file_name.split('.')[0],  # Extract ID from filename
            'gif_file': gif_file_name,
            'file_size': len(gif_bytes),  # Get file size from gif_bytes
            'frame_count': frame_count,
            'frame_rate': frame_rate,
            'frames': frame_paths,  # Store paths to frames in GCS
            'scene_changes': scene_changes,
            'count_key_frames': len(key_frames)  # Add count_key_frames
        }

        return gif_data

    except Exception as e:
        print(f"Error processing GIF {gif_file_name}: {e}")
        return None

def process_gifs(file_path):
    """Processes GIFs listed in a text file."""
    gif_data_list = []
    gif_id_counter = 1
    try:
        # Download the file from GCS
        blob = bucket.blob(file_path)
        file_content = blob.download_as_string().decode('utf-8')

        # Create a dictionary mapping gif_id to gif_description
        descriptions = {}
        for line in file_content.splitlines():
            gif_id, description = line.split(': ')
            descriptions[gif_id] = description

        for line in file_content.splitlines():
            gif_file = line.strip().split(':')[0]  # Extract gif_file from line
            gif_file_name = gif_file + '.gif'  # Assign gif_file to gif_file_name
            gif_data = preprocess_gif(gif_file_name, gif_file)
            if gif_data:
                gif_id = gif_file.split('.')[0]  # Extract gif_id from gif_file
                gif_data['gif_id'] = gif_id  # Assign gif_id
                gif_data['gif_description'] = descriptions.get(gif_id, '')  # Add description from descriptions dictionary
                gif_data_list.append(gif_data)
                gif_id_counter += 1
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

    return gif_data_list

# Process GIFs for each data split
train_data = process_gifs('train_with_description.txt')  #
val_data = process_gifs('val_with_description.txt')
test_data = process_gifs('test_with_description.txt')

# Upload the data to JSON files in GCS
def upload_json_to_gcs(data, filename):
    """Uploads a JSON object to GCS."""
    try:
        json_blob = bucket.blob(filename)
        json_blob.upload_from_string(json.dumps(data, indent=4), content_type='application/json')
        print(f"Uploaded {filename} to GCS")
    except Exception as e:
        print(f"Error uploading {filename} to GCS: {e}")

upload_json_to_gcs(train_data, 'train_data_std.json')
upload_json_to_gcs(val_data, 'val_data_std.json')
upload_json_to_gcs(test_data, 'test_data_std.json')
# Out:
# Error processing GIF 53556.gif: No packer found from P to L
# Frame 0: Empty or has invalid dimensions: (256, 256)
# Frame 1: Empty or has invalid dimensions: (256, 256)
# Frame 2: Empty or has invalid dimensions: (256, 256)
# Frame 3: Empty or has invalid dimensions: (256, 256)
# Frame 4: Empty or has invalid dimensions: (256, 256)
# Frame 5: Empty or has invalid dimensions: (256, 256)
# Frame 6: Empty or has invalid dimensions: (256, 256)
# Frame 7: Empty or has invalid dimensions: (256, 256)
# Frame 8: Empty or has invalid dimensions: (256, 256)
# Frame 9: Empty or has invalid dimensions: (256, 256)
# Frame 10: Empty or has invalid dimensions: (256, 256)
# Frame 11: Empty or has invalid dimensions: (256, 256)
# Frame 12: Empty or has invalid dimensions: (256, 256)
# Frame 13: Empty or has invalid dimensions: (256, 256)
# Frame 14: Empty or has invalid dimensions: (256, 256)
# Frame 15: Empty or has invalid dimensions: (256, 256)
# Frame 16: Empty or has invalid dimensions: (256, 256)
# Frame 17: Empty or has invalid dimensions: (256, 256)
# Frame 18: Empty or has invalid dimensions: (256, 256)
# Frame 19: Empty or has invalid dimensions: (256, 256)
# Frame 20: Empty or has invalid dimensions: (256, 256)
# Frame 21: Empty or has invalid dimensions: (256, 256)
# Frame 22: Empty or has invalid dimensions: (256, 256)
# Frame 23: Empty or has invalid dimensions: (256, 256)
# Frame 24: Empty or has invalid dimensions: (256, 256)
# Frame 25: Empty or has invalid dimensions: (256, 256)
# Frame 26: Empty or has invalid dimensions: (256, 256)
# Frame 27: Empty or has invalid dimensions: (256, 256)
# Frame 28: Empty or has invalid dimensions: (256, 256)
# Error processing GIF 733.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae78810>`` with iomode `r?`.
# Error processing GIF 755.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf80822700>`` with iomode `r?`.
# Error processing GIF 946.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be4c630>`` with iomode `r?`.
# Error processing GIF 603.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf66ed6750>`` with iomode `r?`.
# Error processing GIF 175.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60cc0>`` with iomode `r?`.
# Error processing GIF 150.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0c20>`` with iomode `r?`.
# Error processing GIF 192.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79f80>`` with iomode `r?`.
# Error processing GIF 509.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 841.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79d00>`` with iomode `r?`.
# Error processing GIF 812.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea62f0>`` with iomode `r?`.
# Error processing GIF 525.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32e30>`` with iomode `r?`.
# Error processing GIF 661.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0a40>`` with iomode `r?`.
# Error processing GIF 895.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbabb0>`` with iomode `r?`.
# Error processing GIF 935.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb510>`` with iomode `r?`.
# Error processing GIF 657.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae01260>`` with iomode `r?`.
# Error processing GIF 536.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea5350>`` with iomode `r?`.
# Error processing GIF 740.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fae80>`` with iomode `r?`.
# Error processing GIF 874.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa2f0>`` with iomode `r?`.
# Error processing GIF 842.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02f20>`` with iomode `r?`.
# Error processing GIF 128.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ee30>`` with iomode `r?`.
# Error processing GIF 760.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32d40>`` with iomode `r?`.
# Error processing GIF 9.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2c19f380>`` with iomode `r?`.
# Error processing GIF 560.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa840>`` with iomode `r?`.
# Error processing GIF 152.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 197.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae03dd0>`` with iomode `r?`.
# Error processing GIF 982.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fba60>`` with iomode `r?`.
# Error processing GIF 25.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90fa10>`` with iomode `r?`.
# Error processing GIF 580.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af86ac0>`` with iomode `r?`.
# Error processing GIF 375.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 278.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8faca0>`` with iomode `r?`.
# Error processing GIF 120.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fbfb0>`` with iomode `r?`.
# Error processing GIF 361.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb6f0>`` with iomode `r?`.
# Error processing GIF 725.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0cc0>`` with iomode `r?`.
# Error processing GIF 558.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab2520>`` with iomode `r?`.
# Error processing GIF 578.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a10>`` with iomode `r?`.
# Error processing GIF 47.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae01210>`` with iomode `r?`.
# Error processing GIF 745.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79ad0>`` with iomode `r?`.
# Error processing GIF 638.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea4400>`` with iomode `r?`.
# Error processing GIF 61.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5e570>`` with iomode `r?`.
# Error processing GIF 281.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5ee80>`` with iomode `r?`.
# Error processing GIF 647.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba4a980>`` with iomode `r?`.
# Error processing GIF 338.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae031a0>`` with iomode `r?`.
# Error processing GIF 339.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79d00>`` with iomode `r?`.
# Error processing GIF 496.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea69d0>`` with iomode `r?`.
# Error processing GIF 198.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7a6b0>`` with iomode `r?`.
# Error processing GIF 282.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7060>`` with iomode `r?`.
# Error processing GIF 905.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbb470>`` with iomode `r?`.
# Error processing GIF 590.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ee30>`` with iomode `r?`.
# Error processing GIF 246.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90dc10>`` with iomode `r?`.
# Error processing GIF 898.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae01440>`` with iomode `r?`.
# Error processing GIF 13.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5e570>`` with iomode `r?`.
# Error processing GIF 68.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae03100>`` with iomode `r?`.
# Error processing GIF 748.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5f740>`` with iomode `r?`.
# Error processing GIF 29.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbe3e0>`` with iomode `r?`.
# Error processing GIF 803.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf66ed6750>`` with iomode `r?`.
# Error processing GIF 306.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbabb0>`` with iomode `r?`.
# Error processing GIF 396.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33790>`` with iomode `r?`.
# Error processing GIF 882.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af86ac0>`` with iomode `r?`.
# Error processing GIF 793.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b420>`` with iomode `r?`.
# Error processing GIF 565.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa700>`` with iomode `r?`.
# Error processing GIF 782.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fae30>`` with iomode `r?`.
# Error processing GIF 759.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aee1170>`` with iomode `r?`.
# Error processing GIF 664.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5ee80>`` with iomode `r?`.
# Error processing GIF 33.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33600>`` with iomode `r?`.
# Error processing GIF 184.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea5260>`` with iomode `r?`.
# Error processing GIF 182.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb3d0>`` with iomode `r?`.
# Error processing GIF 365.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb4c0>`` with iomode `r?`.
# Error processing GIF 619.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32d40>`` with iomode `r?`.
# Error processing GIF 626.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7060>`` with iomode `r?`.
# Error processing GIF 707.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f330>`` with iomode `r?`.
# Error processing GIF 190.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90dad0>`` with iomode `r?`.
# Error processing GIF 377.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fbb50>`` with iomode `r?`.
# Error processing GIF 538.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f81d0>`` with iomode `r?`.
# Error processing GIF 263.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa3e0>`` with iomode `r?`.
# Error processing GIF 918.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5fab0>`` with iomode `r?`.
# Error processing GIF 921.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa250>`` with iomode `r?`.
# Error processing GIF 406.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7fb0>`` with iomode `r?`.
# Error processing GIF 348.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f790>`` with iomode `r?`.
# Error processing GIF 220.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ca90>`` with iomode `r?`.
# Error processing GIF 205.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d5d0>`` with iomode `r?`.
# Error processing GIF 507.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bacc2c0>`` with iomode `r?`.
# Error processing GIF 76.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aee1170>`` with iomode `r?`.
# Error processing GIF 110.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be608b0>`` with iomode `r?`.
# Error processing GIF 236.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e520>`` with iomode `r?`.
# Error processing GIF 35.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e340>`` with iomode `r?`.
# Error processing GIF 471.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90cdb0>`` with iomode `r?`.
# Error processing GIF 437.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90dd00>`` with iomode `r?`.
# Error processing GIF 691.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e570>`` with iomode `r?`.
# Error processing GIF 329.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d170>`` with iomode `r?`.
# Error processing GIF 66.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1e5c0>`` with iomode `r?`.
# Error processing GIF 926.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c770>`` with iomode `r?`.
# Error processing GIF 911.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af86b10>`` with iomode `r?`.
# Error processing GIF 521.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90cc20>`` with iomode `r?`.
# Error processing GIF 747.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90de90>`` with iomode `r?`.
# Error processing GIF 73.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d3a0>`` with iomode `r?`.
# Error processing GIF 857.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79ad0>`` with iomode `r?`.
# Error processing GIF 804.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f3d0>`` with iomode `r?`.
# Error processing GIF 213.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f010>`` with iomode `r?`.
# Error processing GIF 646.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d080>`` with iomode `r?`.
# Error processing GIF 270.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31800>`` with iomode `r?`.
# Error processing GIF 467.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33470>`` with iomode `r?`.
# Error processing GIF 598.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8faf20>`` with iomode `r?`.
# Error processing GIF 520.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32d40>`` with iomode `r?`.
# Error processing GIF 239.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33600>`` with iomode `r?`.
# Error processing GIF 262.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f8f40>`` with iomode `r?`.
# Error processing GIF 215.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b330>`` with iomode `r?`.
# Error processing GIF 91.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ffb0>`` with iomode `r?`.
# Error processing GIF 311.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa750>`` with iomode `r?`.
# Error processing GIF 541.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5f830>`` with iomode `r?`.
# Error processing GIF 737.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf80822700>`` with iomode `r?`.
# Error processing GIF 632.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5d800>`` with iomode `r?`.
# Error processing GIF 131.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b5b0>`` with iomode `r?`.
# Error processing GIF 866.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba4a980>`` with iomode `r?`.
# Error processing GIF 135.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbf2e0>`` with iomode `r?`.
# Error processing GIF 678.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31080>`` with iomode `r?`.
# Error processing GIF 433.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87c40>`` with iomode `r?`.
# Error processing GIF 634.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 430.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33600>`` with iomode `r?`.
# Error processing GIF 362.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33470>`` with iomode `r?`.
# Error processing GIF 273.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbe3e0>`` with iomode `r?`.
# Error processing GIF 3.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea4360>`` with iomode `r?`.
# Error processing GIF 880.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa4d0>`` with iomode `r?`.
# Error processing GIF 277.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90eb10>`` with iomode `r?`.
# Error processing GIF 835.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa890>`` with iomode `r?`.
# Error processing GIF 557.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a60>`` with iomode `r?`.
# Error processing GIF 848.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af86ac0>`` with iomode `r?`.
# Error processing GIF 323.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1fce0>`` with iomode `r?`.
# Error processing GIF 552.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea43b0>`` with iomode `r?`.
# Error processing GIF 629.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7fb0>`` with iomode `r?`.
# Error processing GIF 788.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e3e0>`` with iomode `r?`.
# Error processing GIF 79.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c540>`` with iomode `r?`.
# Error processing GIF 814.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918130>`` with iomode `r?`.
# Error processing GIF 4.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 586.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c400>`` with iomode `r?`.
# Error processing GIF 711.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d490>`` with iomode `r?`.
# Error processing GIF 659.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d3a0>`` with iomode `r?`.
# Error processing GIF 676.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf66ed6750>`` with iomode `r?`.
# Error processing GIF 981.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c770>`` with iomode `r?`.
# Error processing GIF 687.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f740>`` with iomode `r?`.
# Error processing GIF 109.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa430>`` with iomode `r?`.
# Error processing GIF 513.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33600>`` with iomode `r?`.
# Error processing GIF 816.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbb330>`` with iomode `r?`.
# Error processing GIF 254.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be608b0>`` with iomode `r?`.
# Error processing GIF 398.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7afc0>`` with iomode `r?`.
# Error processing GIF 601.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f81d0>`` with iomode `r?`.
# Error processing GIF 884.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5dc60>`` with iomode `r?`.
# Error processing GIF 528.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33470>`` with iomode `r?`.
# Error processing GIF 444.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f8a40>`` with iomode `r?`.
# Error processing GIF 318.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32b60>`` with iomode `r?`.
# Error processing GIF 316.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8faed0>`` with iomode `r?`.
# Error processing GIF 206.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea4400>`` with iomode `r?`.
# Error processing GIF 762.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02f20>`` with iomode `r?`.
# Error processing GIF 374.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea4f40>`` with iomode `r?`.
# Error processing GIF 476.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90eca0>`` with iomode `r?`.
# Error processing GIF 90.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae316c0>`` with iomode `r?`.
# Error processing GIF 82.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918720>`` with iomode `r?`.
# Error processing GIF 669.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5d800>`` with iomode `r?`.
# Error processing GIF 410.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbbec0>`` with iomode `r?`.
# Error processing GIF 354.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c540>`` with iomode `r?`.
# Error processing GIF 391.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa4d0>`` with iomode `r?`.
# Error processing GIF 872.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e890>`` with iomode `r?`.
# Error processing GIF 703.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab3560>`` with iomode `r?`.
# Error processing GIF 625.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0c20>`` with iomode `r?`.
# Error processing GIF 799.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5dc60>`` with iomode `r?`.
# Error processing GIF 166.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb8540>`` with iomode `r?`.
# Error processing GIF 877.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa4d0>`` with iomode `r?`.
# Error processing GIF 763.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbf2e0>`` with iomode `r?`.
# Error processing GIF 917.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 431.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1e5c0>`` with iomode `r?`.
# Error processing GIF 312.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1d760>`` with iomode `r?`.
# Error processing GIF 168.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb600>`` with iomode `r?`.
# Error processing GIF 670.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fafc0>`` with iomode `r?`.
# Error processing GIF 1002.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea6520>`` with iomode `r?`.
# Error processing GIF 555.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90efc0>`` with iomode `r?`.
# Error processing GIF 834.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1fce0>`` with iomode `r?`.
# Error processing GIF 42.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbb4c0>`` with iomode `r?`.
# Error processing GIF 472.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b5b0>`` with iomode `r?`.
# Error processing GIF 879.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87bf0>`` with iomode `r?`.
# Error processing GIF 447.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f1a0>`` with iomode `r?`.
# Error processing GIF 296.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d6c0>`` with iomode `r?`.
# Error processing GIF 600.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae00ea0>`` with iomode `r?`.
# Error processing GIF 553.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31760>`` with iomode `r?`.
# Error processing GIF 1013.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918fe0>`` with iomode `r?`.
# Error processing GIF 519.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918810>`` with iomode `r?`.
# Error processing GIF 940.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a840>`` with iomode `r?`.
# Error processing GIF 180.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f8a40>`` with iomode `r?`.
# Error processing GIF 457.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918770>`` with iomode `r?`.
# Error processing GIF 839.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a5c0>`` with iomode `r?`.
# Error processing GIF 98.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bacee80>`` with iomode `r?`.
# Error processing GIF 813.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919300>`` with iomode `r?`.
# Error processing GIF 371.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 500.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aee1170>`` with iomode `r?`.
# Error processing GIF 155.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0a40>`` with iomode `r?`.
# Error processing GIF 257.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87bf0>`` with iomode `r?`.
# Error processing GIF 105.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87c40>`` with iomode `r?`.
# Error processing GIF 978.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90fa60>`` with iomode `r?`.
# Error processing GIF 523.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60b80>`` with iomode `r?`.
# Error processing GIF 250.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea6930>`` with iomode `r?`.
# Error processing GIF 445.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90cb80>`` with iomode `r?`.
# Error processing GIF 750.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbabb0>`` with iomode `r?`.
# Error processing GIF 908.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c540>`` with iomode `r?`.
# Error processing GIF 373.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90dc10>`` with iomode `r?`.
# Error processing GIF 469.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79bc0>`` with iomode `r?`.
# Error processing GIF 547.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f880>`` with iomode `r?`.
# Error processing GIF 202.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33e70>`` with iomode `r?`.
# Error processing GIF 407.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32340>`` with iomode `r?`.
# Error processing GIF 786.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aee30b0>`` with iomode `r?`.
# Error processing GIF 516.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8faed0>`` with iomode `r?`.
# Error processing GIF 347.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb380>`` with iomode `r?`.
# Error processing GIF 234.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b1a0>`` with iomode `r?`.
# Error processing GIF 535.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918a40>`` with iomode `r?`.
# Error processing GIF 773.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a700>`` with iomode `r?`.
# Error processing GIF 963.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ab10>`` with iomode `r?`.
# Error processing GIF 140.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1e5c0>`` with iomode `r?`.
# Error processing GIF 845.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79ad0>`` with iomode `r?`.
# Error processing GIF 275.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33330>`` with iomode `r?`.
# Error processing GIF 833.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79300>`` with iomode `r?`.
# Error processing GIF 6.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b5b0>`` with iomode `r?`.
# Error processing GIF 143.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae01260>`` with iomode `r?`.
# Error processing GIF 417.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02ac0>`` with iomode `r?`.
# Error processing GIF 186.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31df0>`` with iomode `r?`.
# Error processing GIF 770.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf66ed6750>`` with iomode `r?`.
# Error processing GIF 705.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae30c20>`` with iomode `r?`.
# Error processing GIF 819.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa750>`` with iomode `r?`.
# Error processing GIF 602.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5d800>`` with iomode `r?`.
# Error processing GIF 94.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea56c0>`` with iomode `r?`.
# Error processing GIF 101.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c540>`` with iomode `r?`.
# Error processing GIF 462.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2c19f380>`` with iomode `r?`.
# Error processing GIF 991.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90fb50>`` with iomode `r?`.
# Error processing GIF 142.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919210>`` with iomode `r?`.
# Error processing GIF 493.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1e480>`` with iomode `r?`.
# Error processing GIF 941.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb920>`` with iomode `r?`.
# Error processing GIF 429.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5fab0>`` with iomode `r?`.
# Error processing GIF 404.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab2520>`` with iomode `r?`.
# Error processing GIF 387.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7aa20>`` with iomode `r?`.
# Error processing GIF 113.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a5c0>`` with iomode `r?`.
# Error processing GIF 313.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b790>`` with iomode `r?`.
# Error processing GIF 78.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a4d0>`` with iomode `r?`.
# Error processing GIF 84.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91bc40>`` with iomode `r?`.
# Error processing GIF 480.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b150>`` with iomode `r?`.
# Error processing GIF 775.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60cc0>`` with iomode `r?`.
# Error processing GIF 938.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60b80>`` with iomode `r?`.
# Error processing GIF 593.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918db0>`` with iomode `r?`.
# Error processing GIF 810.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91be20>`` with iomode `r?`.
# Error processing GIF 644.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ade0>`` with iomode `r?`.
# Error processing GIF 425.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9195d0>`` with iomode `r?`.
# Error processing GIF 1007.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 141.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918090>`` with iomode `r?`.
# Error processing GIF 615.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ad40>`` with iomode `r?`.
# Error processing GIF 162.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bacee80>`` with iomode `r?`.
# Error processing GIF 203.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea40e0>`` with iomode `r?`.
# Error processing GIF 693.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a10>`` with iomode `r?`.
# Error processing GIF 165.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02ac0>`` with iomode `r?`.
# Error processing GIF 660.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab0c20>`` with iomode `r?`.
# Error processing GIF 666.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae00ea0>`` with iomode `r?`.
# Error processing GIF 304.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ec50>`` with iomode `r?`.
# Error processing GIF 881.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea6930>`` with iomode `r?`.
# Error processing GIF 937.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90cb80>`` with iomode `r?`.
# Error processing GIF 174.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918220>`` with iomode `r?`.
# Error processing GIF 173.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b920>`` with iomode `r?`.
# Error processing GIF 372.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbb330>`` with iomode `r?`.
# Error processing GIF 830.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae328e0>`` with iomode `r?`.
# Error processing GIF 53.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f740>`` with iomode `r?`.
# Error processing GIF 392.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1e5c0>`` with iomode `r?`.
# Error processing GIF 485.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f8360>`` with iomode `r?`.
# Error processing GIF 321.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa430>`` with iomode `r?`.
# Error processing GIF 413.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8f8a40>`` with iomode `r?`.
# Error processing GIF 80.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b80e0>`` with iomode `r?`.
# Error processing GIF 191.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918ae0>`` with iomode `r?`.
# Error processing GIF 889.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33600>`` with iomode `r?`.
# Error processing GIF 543.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba19e40>`` with iomode `r?`.
# Error processing GIF 369.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 894.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae328e0>`` with iomode `r?`.
# Error processing GIF 838.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 136.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31080>`` with iomode `r?`.
# Error processing GIF 702.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bab2520>`` with iomode `r?`.
# Error processing GIF 868.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbb6a0>`` with iomode `r?`.
# Error processing GIF 648.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fae80>`` with iomode `r?`.
# Error processing GIF 718.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e480>`` with iomode `r?`.
# Error processing GIF 722.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90fbf0>`` with iomode `r?`.
# Error processing GIF 562.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b5b0>`` with iomode `r?`.
# Error processing GIF 639.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb830>`` with iomode `r?`.
# Error processing GIF 623.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b060>`` with iomode `r?`.
# Error processing GIF 970.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c590>`` with iomode `r?`.
# Error processing GIF 126.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919c60>`` with iomode `r?`.
# Error processing GIF 510.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb470>`` with iomode `r?`.
# Error processing GIF 488.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae78720>`` with iomode `r?`.
# Error processing GIF 382.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b790>`` with iomode `r?`.
# Error processing GIF 418.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91bab0>`` with iomode `r?`.
# Error processing GIF 95.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae331f0>`` with iomode `r?`.
# Error processing GIF 216.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbab10>`` with iomode `r?`.
# Error processing GIF 989.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa250>`` with iomode `r?`.
# Error processing GIF 930.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a4d0>`` with iomode `r?`.
# Error processing GIF 424.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9184f0>`` with iomode `r?`.
# Error processing GIF 966.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa4d0>`` with iomode `r?`.
# Error processing GIF 533.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9195d0>`` with iomode `r?`.
# Error processing GIF 616.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87c40>`` with iomode `r?`.
# Error processing GIF 854.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918fe0>`` with iomode `r?`.
# Error processing GIF 585.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b790>`` with iomode `r?`.
# Error processing GIF 185.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ba10>`` with iomode `r?`.
# Error processing GIF 456.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a10>`` with iomode `r?`.
# Error processing GIF 969.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60bd0>`` with iomode `r?`.
# Error processing GIF 99.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bacee80>`` with iomode `r?`.
# Error processing GIF 193.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02ac0>`` with iomode `r?`.
# Error processing GIF 189.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae00ea0>`` with iomode `r?`.
# Error processing GIF 89.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 498.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbe3e0>`` with iomode `r?`.
# Error processing GIF 539.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e9d0>`` with iomode `r?`.
# Error processing GIF 411.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ec50>`` with iomode `r?`.
# Error processing GIF 715.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f1a0>`` with iomode `r?`.
# Error processing GIF 455.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adba930>`` with iomode `r?`.
# Error processing GIF 409.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae328e0>`` with iomode `r?`.
# Error processing GIF 32.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9189a0>`` with iomode `r?`.
# Error processing GIF 474.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f740>`` with iomode `r?`.
# Error processing GIF 563.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b5b0>`` with iomode `r?`.
# Error processing GIF 381.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a480>`` with iomode `r?`.
# Error processing GIF 283.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba49300>`` with iomode `r?`.
# Error processing GIF 592.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918f90>`` with iomode `r?`.
# Error processing GIF 674.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918e50>`` with iomode `r?`.
# Error processing GIF 363.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90cf90>`` with iomode `r?`.
# Error processing GIF 181.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b8b80>`` with iomode `r?`.
# Error processing GIF 508.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba49300>`` with iomode `r?`.
# Error processing GIF 641.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bfbe3e0>`` with iomode `r?`.
# Error processing GIF 607.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aee30b0>`` with iomode `r?`.
# Error processing GIF 537.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bacee80>`` with iomode `r?`.
# Error processing GIF 463.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60b80>`` with iomode `r?`.
# Error processing GIF 685.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c450>`` with iomode `r?`.
# Error processing GIF 975.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f740>`` with iomode `r?`.
# Error processing GIF 736.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 7.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02660>`` with iomode `r?`.
# Error processing GIF 230.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f880>`` with iomode `r?`.
# Error processing GIF 267.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a60>`` with iomode `r?`.
# Error processing GIF 434.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae32d40>`` with iomode `r?`.
# Error processing GIF 123.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b100>`` with iomode `r?`.
# Error processing GIF 265.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02480>`` with iomode `r?`.
# Error processing GIF 454.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ae30>`` with iomode `r?`.
# Error processing GIF 218.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fb4c0>`` with iomode `r?`.
# Error processing GIF 64.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91bb00>`` with iomode `r?`.
# Error processing GIF 57.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a918590>`` with iomode `r?`.
# Error processing GIF 334.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919d00>`` with iomode `r?`.
# Error processing GIF 863.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a4d0>`` with iomode `r?`.
# Error processing GIF 171.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9580>`` with iomode `r?`.
# Error processing GIF 243.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919da0>`` with iomode `r?`.
# Error processing GIF 849.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60cc0>`` with iomode `r?`.
# Error processing GIF 887.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9197b0>`` with iomode `r?`.
# Error processing GIF 11.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9ba610>`` with iomode `r?`.
# Error processing GIF 244.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae03100>`` with iomode `r?`.
# Error processing GIF 732.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be60bd0>`` with iomode `r?`.
# Error processing GIF 441.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91aa20>`` with iomode `r?`.
# Error processing GIF 912.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a9d0>`` with iomode `r?`.
# Error processing GIF 714.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adb1cb0>`` with iomode `r?`.
# Error processing GIF 442.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1acf0>`` with iomode `r?`.
# Error processing GIF 860.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ac50>`` with iomode `r?`.
# Error processing GIF 271.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ae30>`` with iomode `r?`.
# Error processing GIF 717.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2bca98f0>`` with iomode `r?`.
# Error processing GIF 949.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af87c40>`` with iomode `r?`.
# Error processing GIF 651.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea7a10>`` with iomode `r?`.
# Error processing GIF 1009.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f4c0>`` with iomode `r?`.
# Error processing GIF 809.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be5fab0>`` with iomode `r?`.
# Error processing GIF 797.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae02480>`` with iomode `r?`.
# Error processing GIF 865.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae79300>`` with iomode `r?`.
# Error processing GIF 692.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1f740>`` with iomode `r?`.
# Error processing GIF 10.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c450>`` with iomode `r?`.
# Error processing GIF 778.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae030b0>`` with iomode `r?`.
# Error processing GIF 390.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae331f0>`` with iomode `r?`.
# Error processing GIF 961.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33e70>`` with iomode `r?`.
# Error processing GIF 551.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbabb0>`` with iomode `r?`.
# Error processing GIF 925.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c090>`` with iomode `r?`.
# Error processing GIF 640.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b81d0>`` with iomode `r?`.
# Error processing GIF 415.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9bb1f0>`` with iomode `r?`.
# Error processing GIF 60.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90d850>`` with iomode `r?`.
# Error processing GIF 683.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b8180>`` with iomode `r?`.
# Error processing GIF 599.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ade0>`` with iomode `r?`.
# Error processing GIF 831.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2adbabb0>`` with iomode `r?`.
# Error processing GIF 353.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae331f0>`` with iomode `r?`.
# Error processing GIF 272.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1c450>`` with iomode `r?`.
# Error processing GIF 487.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae03740>`` with iomode `r?`.
# ...
# Error processing GIF 728.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af90090>`` with iomode `r?`.
# Error processing GIF 222.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af92700>`` with iomode `r?`.
# Error processing GIF 986.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9030>`` with iomode `r?`.
# Error processing GIF 349.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b0810>`` with iomode `r?`.
# Error processing GIF 546.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b09f0>`` with iomode `r?`.
# Error processing GIF 947.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b2340>`` with iomode `r?`.
# Error processing GIF 52.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af92ac0>`` with iomode `r?`.
# Error processing GIF 286.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba48f90>`` with iomode `r?`.
# Error processing GIF 97.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf80822700>`` with iomode `r?`.
# Error processing GIF 386.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33e70>`` with iomode `r?`.
# Error processing GIF 836.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31f80>`` with iomode `r?`.
# Error processing GIF 959.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9030>`` with iomode `r?`.
# Error processing GIF 223.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9ba610>`` with iomode `r?`.
# Error processing GIF 517.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3a10>`` with iomode `r?`.
# Error processing GIF 699.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b1ad0>`` with iomode `r?`.
# Error processing GIF 939.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b36a0>`` with iomode `r?`.
# Error processing GIF 200.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9bb010>`` with iomode `r?`.
# Error processing GIF 129.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b0220>`` with iomode `r?`.
# Error processing GIF 708.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9300>`` with iomode `r?`.
# Error processing GIF 988.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2aea4f40>`` with iomode `r?`.
# Error processing GIF 589.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ba1af20>`` with iomode `r?`.
# Error processing GIF 364.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b0c20>`` with iomode `r?`.
# Error processing GIF 764.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b0cc0>`` with iomode `r?`.
# Error processing GIF 63.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3b00>`` with iomode `r?`.
# Error processing GIF 964.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af91da0>`` with iomode `r?`.
# Error processing GIF 995.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b1f80>`` with iomode `r?`.
# Error processing GIF 888.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8fa7f0>`` with iomode `r?`.
# Error processing GIF 330.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a8faa70>`` with iomode `r?`.
# Error processing GIF 77.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af936a0>`` with iomode `r?`.
# Error processing GIF 783.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af92520>`` with iomode `r?`.
# Error processing GIF 159.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99cd10>`` with iomode `r?`.
# Error processing GIF 1008.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919b20>`` with iomode `r?`.
# Error processing GIF 751.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9a80>`` with iomode `r?`.
# Error processing GIF 440.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f920>`` with iomode `r?`.
# Error processing GIF 470.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b17b0>`` with iomode `r?`.
# Error processing GIF 380.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af92d90>`` with iomode `r?`.
# Error processing GIF 822.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8fab0>`` with iomode `r?`.
# Error processing GIF 530.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8c540>`` with iomode `r?`.
# Error processing GIF 846.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af901d0>`` with iomode `r?`.
# Error processing GIF 624.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8ce50>`` with iomode `r?`.
# Error processing GIF 458.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8dc60>`` with iomode `r?`.
# Error processing GIF 766.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99f2e0>`` with iomode `r?`.
# Error processing GIF 125.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af925c0>`` with iomode `r?`.
# Error processing GIF 990.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8d620>`` with iomode `r?`.
# Error processing GIF 384.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3c90>`` with iomode `r?`.
# Error processing GIF 465.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8d3f0>`` with iomode `r?`.
# Error processing GIF 238.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8e7a0>`` with iomode `r?`.
# Error processing GIF 314.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8f290>`` with iomode `r?`.
# Error processing GIF 827.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8fab0>`` with iomode `r?`.
# Error processing GIF 228.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33e70>`` with iomode `r?`.
# Error processing GIF 829.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31f80>`` with iomode `r?`.
# Error processing GIF 856.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7ad40>`` with iomode `r?`.
# Error processing GIF 299.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8dee0>`` with iomode `r?`.
# Error processing GIF 1012.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a660>`` with iomode `r?`.
# Error processing GIF 588.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919e40>`` with iomode `r?`.
# Error processing GIF 419.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8f790>`` with iomode `r?`.
# Error processing GIF 252.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8db20>`` with iomode `r?`.
# Error processing GIF 901.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8fd30>`` with iomode `r?`.
# Error processing GIF 37.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8fc90>`` with iomode `r?`.
# Error processing GIF 575.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8e480>`` with iomode `r?`.
# Error processing GIF 658.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99d170>`` with iomode `r?`.
# Error processing GIF 19.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8cdb0>`` with iomode `r?`.
# Error processing GIF 622.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99e7f0>`` with iomode `r?`.
# Error processing GIF 309.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a0c0>`` with iomode `r?`.
# Error processing GIF 8.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8cc20>`` with iomode `r?`.
# Error processing GIF 199.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b600>`` with iomode `r?`.
# Error processing GIF 955.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99d0d0>`` with iomode `r?`.
# Error processing GIF 300.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99dfd0>`` with iomode `r?`.
# Error processing GIF 545.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90ffb0>`` with iomode `r?`.
# Error processing GIF 785.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99fdd0>`` with iomode `r?`.
# Error processing GIF 69.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e110>`` with iomode `r?`.
# Error processing GIF 506.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91ba60>`` with iomode `r?`.
# Error processing GIF 954.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b36a0>`` with iomode `r?`.
# Error processing GIF 605.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b1710>`` with iomode `r?`.
# Error processing GIF 491.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af90900>`` with iomode `r?`.
# Error processing GIF 672.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3d30>`` with iomode `r?`.
# Error processing GIF 416.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae018f0>`` with iomode `r?`.
# Error processing GIF 653.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f970>`` with iomode `r?`.
# Error processing GIF 274.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b34c0>`` with iomode `r?`.
# Error processing GIF 915.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b90d0>`` with iomode `r?`.
# Error processing GIF 461.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b1710>`` with iomode `r?`.
# Error processing GIF 504.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae1fe70>`` with iomode `r?`.
# Error processing GIF 31.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b17b0>`` with iomode `r?`.
# Error processing GIF 242.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99ed90>`` with iomode `r?`.
# Error processing GIF 85.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99e3e0>`` with iomode `r?`.
# Error processing GIF 322.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99c270>`` with iomode `r?`.
# Error processing GIF 958.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be609f0>`` with iomode `r?`.
# Error processing GIF 662.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9ee0>`` with iomode `r?`.
# Error processing GIF 88.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae33e70>`` with iomode `r?`.
# Error processing GIF 376.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b9030>`` with iomode `r?`.
# Error processing GIF 739.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae31f80>`` with iomode `r?`.
# Error processing GIF 479.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90fce0>`` with iomode `r?`.
# Error processing GIF 511.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919e90>`` with iomode `r?`.
# Error processing GIF 713.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99ff60>`` with iomode `r?`.
# Error processing GIF 861.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8ce50>`` with iomode `r?`.
# Error processing GIF 582.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99f4c0>`` with iomode `r?`.
# Error processing GIF 719.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90f8d0>`` with iomode `r?`.
# Error processing GIF 723.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2d7213f0>`` with iomode `r?`.
# Error processing GIF 370.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8e1b0>`` with iomode `r?`.
# Error processing GIF 697.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b21b0>`` with iomode `r?`.
# Error processing GIF 728.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2be609f0>`` with iomode `r?`.
# Error processing GIF 222.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8d120>`` with iomode `r?`.
# Error processing GIF 986.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8fec0>`` with iomode `r?`.
# Error processing GIF 349.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7b6f0>`` with iomode `r?`.
# Error processing GIF 546.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2d7213f0>`` with iomode `r?`.
# Error processing GIF 947.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9189f0>`` with iomode `r?`.
# Error processing GIF 52.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2ae7ad40>`` with iomode `r?`.
# Error processing GIF 286.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919990>`` with iomode `r?`.
# Error processing GIF 97.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99d9e0>`` with iomode `r?`.
# Error processing GIF 386.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8f470>`` with iomode `r?`.
# Error processing GIF 836.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9bbf60>`` with iomode `r?`.
# Error processing GIF 959.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9ba750>`` with iomode `r?`.
# Error processing GIF 223.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8d5d0>`` with iomode `r?`.
# Error processing GIF 517.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8d170>`` with iomode `r?`.
# Error processing GIF 699.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a99dfd0>`` with iomode `r?`.
# Error processing GIF 939.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3a10>`` with iomode `r?`.
# Error processing GIF 200.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8f970>`` with iomode `r?`.
# Error processing GIF 129.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8ec00>`` with iomode `r?`.
# Error processing GIF 708.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90e520>`` with iomode `r?`.
# Error processing GIF 988.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91a570>`` with iomode `r?`.
# Error processing GIF 589.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af938d0>`` with iomode `r?`.
# Error processing GIF 364.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91af20>`` with iomode `r?`.
# Error processing GIF 764.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af8eca0>`` with iomode `r?`.
# Error processing GIF 63.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a919b20>`` with iomode `r?`.
# Error processing GIF 964.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a90c5e0>`` with iomode `r?`.
# Error processing GIF 995.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a91b2e0>`` with iomode `r?`.
# Error processing GIF 888.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b90d0>`` with iomode `r?`.
# Error processing GIF 330.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2af90bd0>`` with iomode `r?`.
# Error processing GIF 77.gif: Could not find a backend to open `<_io.BytesIO object at 0x7ecf2a9b3fb0>`` with iomode `r?`.
# Uploaded train_data_std.json to GCS
# Uploaded val_data_std.json to GCS
# Uploaded test_data_std.json to GCS

# %% [markdown]
# # **List Generator**

# %%
import os
import json
import imageio
import cv2
import numpy as np
from io import BytesIO
from skimage.metrics import structural_similarity as ssim
from google.cloud import storage
from google.colab import auth

auth.authenticate_user()

# Set up Google Cloud Storage client
storage_client = storage.Client()
bucket_name = 'gif-bucket-1000'
bucket = storage_client.bucket(bucket_name)

def resize_and_normalize_frame(frame, target_size=(256, 256)):
    """Resize and normalize the frame while preserving aspect ratio."""
    original_height, original_width = frame.shape[:2]
    aspect_ratio = original_width / original_height

    if aspect_ratio > 1:  # Wider than tall
        new_width = target_size[0]
        new_height = int(target_size[0] / aspect_ratio)
    else:  # Taller than wide or square
        new_width = int(target_size[1] * aspect_ratio)
        new_height = target_size[1]

    resized_frame = cv2.resize(frame, (new_width, new_height))

    # Calculate padding
    delta_w = target_size[0] - new_width
    delta_h = target_size[1] - new_height
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Add padding to maintain the target size
    normalized_frame = cv2.copyMakeBorder(resized_frame, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    normalized_frame = normalized_frame.astype(np.float32) / 255.0

    return normalized_frame

def augment_frame(frame):
    """Apply random data augmentation to the frame."""
    if np.random.rand() < 0.5:
        frame = cv2.flip(frame, 1)  # Horizontal flip
    if np.random.rand() < 0.5:
        rows, cols = frame.shape[:2]
        rotation_angle = np.random.randint(-10, 10)
        M = cv2.getRotationMatrix2D((cols/2, rows/2), rotation_angle, 1)
        frame = cv2.warpAffine(frame, M, (cols, rows))
    return frame

def extract_key_frames(frames, ssim_threshold=0.95, min_scene_change=10, max_key_frames=10):  # Changed max_key_frames
    """Extract key frames based on structural similarity."""
    key_frames = []
    prev_frame = None
    scene_change_counter = 0
    scene_changes = []  # Initialize scene_changes here

    for i, frame in enumerate(frames):
        if not isinstance(frame, np.ndarray):
            print(f"Frame {i}: Not a valid NumPy array.")
            continue

        if frame.size == 0 or len(frame.shape) != 3:
            print(f"Frame {i}: Empty or has invalid dimensions: {frame.shape if isinstance(frame, np.ndarray) else 'N/A'}")
            continue

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)

        if prev_frame is None:
            key_frames.append(frame)
            prev_frame = gray_frame
            continue

        similarity_score = ssim(prev_frame, gray_frame, data_range=1.0)

        if similarity_score < ssim_threshold:
            scene_change_counter += 1
            if scene_change_counter >= min_scene_change and len(key_frames) < max_key_frames:  # Check max_key_frames
                key_frames.append(frame)
                scene_changes.append(i)  # Add index to scene_changes
                scene_change_counter = 0
        else:
            scene_change_counter = 0

        prev_frame = gray_frame

    # Repeat last frame if less than max_key_frames
    while len(key_frames) < max_key_frames:
        key_frames.append(key_frames[-1])

    return key_frames, scene_changes  # Return scene_changes

def process_gif(gif_file_name):
    """Preprocesses a GIF from GCS and extracts 10 key frames."""
    try:
        gif_blob = bucket.blob(os.path.join('gifs', gif_file_name))
        gif_bytes = gif_blob.download_as_bytes()

        with imageio.get_reader(BytesIO(gif_bytes), 'gif') as reader:
            processed_frames = []
            for frame in reader:
                if frame.shape[-1] == 4:
                    frame = cv2.cvtColor(frame, cv2.COLOR_RGBA2RGB)
                resized_frame = resize_and_normalize_frame(frame)
                augmented_frame = augment_frame(resized_frame)
                processed_frames.append(augmented_frame)

        key_frames, _ = extract_key_frames(processed_frames)

        return key_frames

    except Exception as e:
        print(f"Error processing GIF {gif_file_name}: {e}")
        return None

def generate_data(file_path):
    """Generates target_frames and target_texts from a text file."""
    target_frames = []
    target_texts = []
    try:
        # Download the file from GCS
        blob = bucket.blob(file_path)
        file_content = blob.download_as_string().decode('utf-8')

        for line in file_content.splitlines():
            gif_file, description = line.strip().split(': ')
            key_frames = process_gif(gif_file+'.gif')
            if key_frames:
                target_frames.append(key_frames)
                target_texts.append(description)

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

    return target_frames, target_texts

# Generate data for each split
train_frames, train_texts = generate_data('train_with_description.txt')
test_frames, test_texts = generate_data('test_with_description.txt')
val_frames, val_texts = generate_data('val_with_description.txt')
# Out:
# Error processing GIF 53556.gif: No packer found from P to L
# Frame 0: Empty or has invalid dimensions: (256, 256)
# Frame 1: Empty or has invalid dimensions: (256, 256)
# Frame 2: Empty or has invalid dimensions: (256, 256)
# Frame 3: Empty or has invalid dimensions: (256, 256)
# Frame 4: Empty or has invalid dimensions: (256, 256)
# Frame 5: Empty or has invalid dimensions: (256, 256)
# Frame 6: Empty or has invalid dimensions: (256, 256)
# Frame 7: Empty or has invalid dimensions: (256, 256)
# Frame 8: Empty or has invalid dimensions: (256, 256)
# Frame 9: Empty or has invalid dimensions: (256, 256)
# Frame 10: Empty or has invalid dimensions: (256, 256)
# Frame 11: Empty or has invalid dimensions: (256, 256)
# Frame 12: Empty or has invalid dimensions: (256, 256)
# Frame 13: Empty or has invalid dimensions: (256, 256)
# Frame 14: Empty or has invalid dimensions: (256, 256)
# Frame 15: Empty or has invalid dimensions: (256, 256)
# Frame 16: Empty or has invalid dimensions: (256, 256)
# Frame 17: Empty or has invalid dimensions: (256, 256)
# Frame 18: Empty or has invalid dimensions: (256, 256)
# Frame 19: Empty or has invalid dimensions: (256, 256)
# Frame 20: Empty or has invalid dimensions: (256, 256)
# Frame 21: Empty or has invalid dimensions: (256, 256)
# Frame 22: Empty or has invalid dimensions: (256, 256)
# Frame 23: Empty or has invalid dimensions: (256, 256)
# Frame 24: Empty or has invalid dimensions: (256, 256)
# Frame 25: Empty or has invalid dimensions: (256, 256)
# Frame 26: Empty or has invalid dimensions: (256, 256)
# Frame 27: Empty or has invalid dimensions: (256, 256)
# Frame 28: Empty or has invalid dimensions: (256, 256)
# Error processing GIF 12946.gif: list index out of range
# Error processing GIF 733.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc6d0>`` with iomode `r?`.
# Error processing GIF 755.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa03dd800>`` with iomode `r?`.
# Error processing GIF 946.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060c3b0>`` with iomode `r?`.
# Error processing GIF 603.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cd030>`` with iomode `r?`.
# Error processing GIF 175.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa012e200>`` with iomode `r?`.
# Error processing GIF 150.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152700>`` with iomode `r?`.
# Error processing GIF 192.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d83b0>`` with iomode `r?`.
# Error processing GIF 509.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068fa10>`` with iomode `r?`.
# Error processing GIF 841.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068ffb0>`` with iomode `r?`.
# Error processing GIF 812.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184450>`` with iomode `r?`.
# Error processing GIF 525.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184540>`` with iomode `r?`.
# Error processing GIF 661.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184950>`` with iomode `r?`.
# Error processing GIF 895.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185800>`` with iomode `r?`.
# Error processing GIF 935.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068f290>`` with iomode `r?`.
# Error processing GIF 657.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185530>`` with iomode `r?`.
# Error processing GIF 536.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01853f0>`` with iomode `r?`.
# Error processing GIF 740.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01857b0>`` with iomode `r?`.
# Error processing GIF 874.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186a70>`` with iomode `r?`.
# Error processing GIF 842.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068ecf0>`` with iomode `r?`.
# Error processing GIF 128.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01849f0>`` with iomode `r?`.
# Error processing GIF 760.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186160>`` with iomode `r?`.
# Error processing GIF 9.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0969da0>`` with iomode `r?`.
# Error processing GIF 560.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa3cec720>`` with iomode `r?`.
# Error processing GIF 152.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e0ea0>`` with iomode `r?`.
# Error processing GIF 197.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 982.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cf9c0>`` with iomode `r?`.
# Error processing GIF 25.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01527a0>`` with iomode `r?`.
# Error processing GIF 580.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 375.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01865c0>`` with iomode `r?`.
# Error processing GIF 278.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce2f0>`` with iomode `r?`.
# Error processing GIF 120.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153100>`` with iomode `r?`.
# Error processing GIF 361.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187e70>`` with iomode `r?`.
# Error processing GIF 725.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187d80>`` with iomode `r?`.
# Error processing GIF 558.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185940>`` with iomode `r?`.
# Error processing GIF 578.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184900>`` with iomode `r?`.
# Error processing GIF 47.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184860>`` with iomode `r?`.
# Error processing GIF 745.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185490>`` with iomode `r?`.
# Error processing GIF 638.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187920>`` with iomode `r?`.
# Error processing GIF 61.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01528e0>`` with iomode `r?`.
# Error processing GIF 281.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc3b0>`` with iomode `r?`.
# Error processing GIF 647.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184270>`` with iomode `r?`.
# Error processing GIF 338.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184540>`` with iomode `r?`.
# Error processing GIF 339.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165ad0>`` with iomode `r?`.
# Error processing GIF 496.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01674c0>`` with iomode `r?`.
# Error processing GIF 198.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153470>`` with iomode `r?`.
# Error processing GIF 282.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01841d0>`` with iomode `r?`.
# Error processing GIF 905.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165d00>`` with iomode `r?`.
# Error processing GIF 590.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01524d0>`` with iomode `r?`.
# Error processing GIF 246.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01878d0>`` with iomode `r?`.
# Error processing GIF 898.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164450>`` with iomode `r?`.
# Error processing GIF 13.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186e30>`` with iomode `r?`.
# Error processing GIF 68.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184770>`` with iomode `r?`.
# Error processing GIF 748.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01845e0>`` with iomode `r?`.
# Error processing GIF 29.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185d50>`` with iomode `r?`.
# Error processing GIF 803.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184cc0>`` with iomode `r?`.
# Error processing GIF 306.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184680>`` with iomode `r?`.
# Error processing GIF 396.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187060>`` with iomode `r?`.
# Error processing GIF 882.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186c50>`` with iomode `r?`.
# Error processing GIF 793.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b00>`` with iomode `r?`.
# Error processing GIF 565.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce0c0>`` with iomode `r?`.
# Error processing GIF 782.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068fa10>`` with iomode `r?`.
# Error processing GIF 759.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186840>`` with iomode `r?`.
# Error processing GIF 664.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152890>`` with iomode `r?`.
# Error processing GIF 33.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc630>`` with iomode `r?`.
# Error processing GIF 184.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfbf0>`` with iomode `r?`.
# Error processing GIF 182.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187ce0>`` with iomode `r?`.
# Error processing GIF 365.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185030>`` with iomode `r?`.
# Error processing GIF 619.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068fce0>`` with iomode `r?`.
# Error processing GIF 626.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01644f0>`` with iomode `r?`.
# Error processing GIF 707.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01870b0>`` with iomode `r?`.
# Error processing GIF 190.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b50>`` with iomode `r?`.
# Error processing GIF 377.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164e50>`` with iomode `r?`.
# Error processing GIF 538.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167b00>`` with iomode `r?`.
# Error processing GIF 263.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187bf0>`` with iomode `r?`.
# Error processing GIF 918.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152610>`` with iomode `r?`.
# Error processing GIF 921.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167010>`` with iomode `r?`.
# Error processing GIF 406.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 348.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa012cf40>`` with iomode `r?`.
# Error processing GIF 220.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b50>`` with iomode `r?`.
# Error processing GIF 205.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185030>`` with iomode `r?`.
# Error processing GIF 507.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185e90>`` with iomode `r?`.
# Error processing GIF 76.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185490>`` with iomode `r?`.
# Error processing GIF 110.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068f290>`` with iomode `r?`.
# Error processing GIF 236.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184270>`` with iomode `r?`.
# Error processing GIF 35.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01879c0>`` with iomode `r?`.
# Error processing GIF 471.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186ca0>`` with iomode `r?`.
# Error processing GIF 437.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01865c0>`` with iomode `r?`.
# Error processing GIF 691.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068eb60>`` with iomode `r?`.
# Error processing GIF 329.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153100>`` with iomode `r?`.
# Error processing GIF 66.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfd30>`` with iomode `r?`.
# Error processing GIF 926.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce610>`` with iomode `r?`.
# Error processing GIF 911.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01859e0>`` with iomode `r?`.
# Error processing GIF 521.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01841d0>`` with iomode `r?`.
# Error processing GIF 747.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165120>`` with iomode `r?`.
# Error processing GIF 73.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01853a0>`` with iomode `r?`.
# Error processing GIF 857.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 804.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165350>`` with iomode `r?`.
# Error processing GIF 213.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165bc0>`` with iomode `r?`.
# Error processing GIF 646.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185ee0>`` with iomode `r?`.
# Error processing GIF 270.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167970>`` with iomode `r?`.
# Error processing GIF 467.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfc40>`` with iomode `r?`.
# Error processing GIF 598.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 520.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184ef0>`` with iomode `r?`.
# Error processing GIF 239.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce3e0>`` with iomode `r?`.
# Error processing GIF 262.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01527a0>`` with iomode `r?`.
# Error processing GIF 215.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfc40>`` with iomode `r?`.
# Error processing GIF 91.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e70>`` with iomode `r?`.
# Error processing GIF 311.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdbf0b290>`` with iomode `r?`.
# Error processing GIF 541.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184a40>`` with iomode `r?`.
# Error processing GIF 737.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185ad0>`` with iomode `r?`.
# Error processing GIF 632.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d87c0>`` with iomode `r?`.
# Error processing GIF 131.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce110>`` with iomode `r?`.
# Error processing GIF 866.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186980>`` with iomode `r?`.
# Error processing GIF 135.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e0950>`` with iomode `r?`.
# Error processing GIF 678.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 433.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185cb0>`` with iomode `r?`.
# Error processing GIF 634.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185260>`` with iomode `r?`.
# Error processing GIF 430.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060c3b0>`` with iomode `r?`.
# Error processing GIF 362.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01671a0>`` with iomode `r?`.
# Error processing GIF 273.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068fa10>`` with iomode `r?`.
# Error processing GIF 3.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153470>`` with iomode `r?`.
# Error processing GIF 880.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153790>`` with iomode `r?`.
# Error processing GIF 277.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cdb20>`` with iomode `r?`.
# Error processing GIF 835.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187d30>`` with iomode `r?`.
# Error processing GIF 557.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187f60>`` with iomode `r?`.
# Error processing GIF 848.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164680>`` with iomode `r?`.
# Error processing GIF 323.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01854e0>`` with iomode `r?`.
# Error processing GIF 552.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165170>`` with iomode `r?`.
# Error processing GIF 629.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165f30>`` with iomode `r?`.
# Error processing GIF 788.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164590>`` with iomode `r?`.
# Error processing GIF 79.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04371f0>`` with iomode `r?`.
# Error processing GIF 814.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa012e200>`` with iomode `r?`.
# Error processing GIF 4.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdbf0b290>`` with iomode `r?`.
# Error processing GIF 586.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185670>`` with iomode `r?`.
# Error processing GIF 711.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186ed0>`` with iomode `r?`.
# Error processing GIF 659.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01846d0>`` with iomode `r?`.
# Error processing GIF 676.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153b00>`` with iomode `r?`.
# Error processing GIF 981.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 687.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 109.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068f880>`` with iomode `r?`.
# Error processing GIF 513.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184bd0>`` with iomode `r?`.
# Error processing GIF 816.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ccea0>`` with iomode `r?`.
# Error processing GIF 254.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b00>`` with iomode `r?`.
# Error processing GIF 398.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce610>`` with iomode `r?`.
# Error processing GIF 601.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01873d0>`` with iomode `r?`.
# Error processing GIF 884.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185210>`` with iomode `r?`.
# Error processing GIF 528.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01849f0>`` with iomode `r?`.
# Error processing GIF 444.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187c40>`` with iomode `r?`.
# Error processing GIF 318.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01644a0>`` with iomode `r?`.
# Error processing GIF 316.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc3b0>`` with iomode `r?`.
# Error processing GIF 206.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164180>`` with iomode `r?`.
# Error processing GIF 762.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187970>`` with iomode `r?`.
# Error processing GIF 374.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01875b0>`` with iomode `r?`.
# Error processing GIF 476.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01904a0>`` with iomode `r?`.
# Error processing GIF 90.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01644f0>`` with iomode `r?`.
# Error processing GIF 82.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 669.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce430>`` with iomode `r?`.
# Error processing GIF 410.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cda80>`` with iomode `r?`.
# Error processing GIF 354.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfb50>`` with iomode `r?`.
# Error processing GIF 391.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 872.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164a90>`` with iomode `r?`.
# Error processing GIF 703.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 625.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01650d0>`` with iomode `r?`.
# Error processing GIF 799.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185300>`` with iomode `r?`.
# Error processing GIF 166.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184bd0>`` with iomode `r?`.
# Error processing GIF 877.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b00>`` with iomode `r?`.
# Error processing GIF 763.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01653a0>`` with iomode `r?`.
# Error processing GIF 917.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01659e0>`` with iomode `r?`.
# Error processing GIF 431.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 312.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e0950>`` with iomode `r?`.
# Error processing GIF 168.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186840>`` with iomode `r?`.
# Error processing GIF 670.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187f60>`` with iomode `r?`.
# Error processing GIF 1002.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1530>`` with iomode `r?`.
# Error processing GIF 555.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01842c0>`` with iomode `r?`.
# Error processing GIF 834.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190c20>`` with iomode `r?`.
# Error processing GIF 42.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190130>`` with iomode `r?`.
# Error processing GIF 472.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfce0>`` with iomode `r?`.
# Error processing GIF 879.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060c3b0>`` with iomode `r?`.
# Error processing GIF 447.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165170>`` with iomode `r?`.
# Error processing GIF 296.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166980>`` with iomode `r?`.
# Error processing GIF 600.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01849f0>`` with iomode `r?`.
# Error processing GIF 553.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068f290>`` with iomode `r?`.
# Error processing GIF 1013.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d83b0>`` with iomode `r?`.
# Error processing GIF 519.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187f10>`` with iomode `r?`.
# Error processing GIF 940.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185da0>`` with iomode `r?`.
# Error processing GIF 180.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187330>`` with iomode `r?`.
# Error processing GIF 457.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d87c0>`` with iomode `r?`.
# Error processing GIF 839.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185940>`` with iomode `r?`.
# Error processing GIF 98.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153790>`` with iomode `r?`.
# Error processing GIF 813.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01871a0>`` with iomode `r?`.
# Error processing GIF 371.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e70>`` with iomode `r?`.
# Error processing GIF 500.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01848b0>`` with iomode `r?`.
# Error processing GIF 155.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167b00>`` with iomode `r?`.
# Error processing GIF 257.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164cc0>`` with iomode `r?`.
# Error processing GIF 105.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184860>`` with iomode `r?`.
# Error processing GIF 978.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185ee0>`` with iomode `r?`.
# Error processing GIF 523.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01673d0>`` with iomode `r?`.
# Error processing GIF 250.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce610>`` with iomode `r?`.
# Error processing GIF 445.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185ad0>`` with iomode `r?`.
# Error processing GIF 750.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166160>`` with iomode `r?`.
# Error processing GIF 908.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0812520>`` with iomode `r?`.
# Error processing GIF 373.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191d00>`` with iomode `r?`.
# Error processing GIF 469.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01927f0>`` with iomode `r?`.
# Error processing GIF 547.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23b380>`` with iomode `r?`.
# Error processing GIF 202.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01643b0>`` with iomode `r?`.
# Error processing GIF 407.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 786.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1530>`` with iomode `r?`.
# Error processing GIF 516.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d8270>`` with iomode `r?`.
# Error processing GIF 347.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 234.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b1a0>`` with iomode `r?`.
# Error processing GIF 535.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153470>`` with iomode `r?`.
# Error processing GIF 773.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01644f0>`` with iomode `r?`.
# Error processing GIF 963.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01669d0>`` with iomode `r?`.
# Error processing GIF 140.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185210>`` with iomode `r?`.
# Error processing GIF 845.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01655d0>`` with iomode `r?`.
# Error processing GIF 275.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068f290>`` with iomode `r?`.
# Error processing GIF 833.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cee80>`` with iomode `r?`.
# Error processing GIF 6.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166cf0>`` with iomode `r?`.
# Error processing GIF 143.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165210>`` with iomode `r?`.
# Error processing GIF 417.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 186.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01866b0>`` with iomode `r?`.
# Error processing GIF 770.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191800>`` with iomode `r?`.
# Error processing GIF 705.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192d40>`` with iomode `r?`.
# Error processing GIF 819.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192390>`` with iomode `r?`.
# Error processing GIF 602.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191d00>`` with iomode `r?`.
# Error processing GIF 94.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193150>`` with iomode `r?`.
# Error processing GIF 101.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d87c0>`` with iomode `r?`.
# Error processing GIF 462.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 991.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e20>`` with iomode `r?`.
# Error processing GIF 142.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 493.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 941.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23b380>`` with iomode `r?`.
# Error processing GIF 429.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185800>`` with iomode `r?`.
# Error processing GIF 404.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187c90>`` with iomode `r?`.
# Error processing GIF 387.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfd80>`` with iomode `r?`.
# Error processing GIF 113.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186160>`` with iomode `r?`.
# Error processing GIF 313.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186340>`` with iomode `r?`.
# Error processing GIF 78.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165080>`` with iomode `r?`.
# Error processing GIF 84.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01665c0>`` with iomode `r?`.
# Error processing GIF 480.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01531f0>`` with iomode `r?`.
# Error processing GIF 775.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191e90>`` with iomode `r?`.
# Error processing GIF 938.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193240>`` with iomode `r?`.
# Error processing GIF 593.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b740>`` with iomode `r?`.
# Error processing GIF 810.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193560>`` with iomode `r?`.
# Error processing GIF 644.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192980>`` with iomode `r?`.
# Error processing GIF 425.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191170>`` with iomode `r?`.
# Error processing GIF 1007.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01914e0>`` with iomode `r?`.
# Error processing GIF 141.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193d30>`` with iomode `r?`.
# Error processing GIF 615.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193100>`` with iomode `r?`.
# Error processing GIF 162.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193ab0>`` with iomode `r?`.
# Error processing GIF 203.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193ce0>`` with iomode `r?`.
# Error processing GIF 693.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164180>`` with iomode `r?`.
# Error processing GIF 165.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193650>`` with iomode `r?`.
# Error processing GIF 660.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01850d0>`` with iomode `r?`.
# Error processing GIF 666.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01918a0>`` with iomode `r?`.
# Error processing GIF 304.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01925c0>`` with iomode `r?`.
# Error processing GIF 881.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184b80>`` with iomode `r?`.
# Error processing GIF 937.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193650>`` with iomode `r?`.
# Error processing GIF 174.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01925c0>`` with iomode `r?`.
# Error processing GIF 173.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01911c0>`` with iomode `r?`.
# Error processing GIF 372.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192480>`` with iomode `r?`.
# Error processing GIF 830.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193b50>`` with iomode `r?`.
# Error processing GIF 53.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193010>`` with iomode `r?`.
# Error processing GIF 392.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 485.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190900>`` with iomode `r?`.
# Error processing GIF 321.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01938d0>`` with iomode `r?`.
# Error processing GIF 413.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167600>`` with iomode `r?`.
# Error processing GIF 80.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3970>`` with iomode `r?`.
# Error processing GIF 191.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190ef0>`` with iomode `r?`.
# Error processing GIF 889.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166cf0>`` with iomode `r?`.
# Error processing GIF 543.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 369.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 894.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfc40>`` with iomode `r?`.
# Error processing GIF 838.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cdda0>`` with iomode `r?`.
# Error processing GIF 136.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ccea0>`` with iomode `r?`.
# Error processing GIF 702.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191990>`` with iomode `r?`.
# Error processing GIF 868.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d83b0>`` with iomode `r?`.
# Error processing GIF 648.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b1a0>`` with iomode `r?`.
# Error processing GIF 718.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23b420>`` with iomode `r?`.
# Error processing GIF 722.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185030>`` with iomode `r?`.
# Error processing GIF 562.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d3a0>`` with iomode `r?`.
# Error processing GIF 639.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018c720>`` with iomode `r?`.
# Error processing GIF 623.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165a30>`` with iomode `r?`.
# Error processing GIF 970.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d120>`` with iomode `r?`.
# Error processing GIF 126.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa012e200>`` with iomode `r?`.
# Error processing GIF 510.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 488.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153dd0>`` with iomode `r?`.
# Error processing GIF 382.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 418.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0187b00>`` with iomode `r?`.
# Error processing GIF 95.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cf380>`` with iomode `r?`.
# Error processing GIF 216.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f60>`` with iomode `r?`.
# Error processing GIF 989.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01665c0>`` with iomode `r?`.
# Error processing GIF 930.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cf9c0>`` with iomode `r?`.
# Error processing GIF 424.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166ca0>`` with iomode `r?`.
# Error processing GIF 966.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185ee0>`` with iomode `r?`.
# Error processing GIF 533.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3920>`` with iomode `r?`.
# Error processing GIF 616.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191fd0>`` with iomode `r?`.
# Error processing GIF 854.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192bb0>`` with iomode `r?`.
# Error processing GIF 585.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192c00>`` with iomode `r?`.
# Error processing GIF 185.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190540>`` with iomode `r?`.
# Error processing GIF 456.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193740>`` with iomode `r?`.
# Error processing GIF 969.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01843b0>`` with iomode `r?`.
# Error processing GIF 99.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01918a0>`` with iomode `r?`.
# Error processing GIF 193.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193150>`` with iomode `r?`.
# Error processing GIF 189.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184b80>`` with iomode `r?`.
# Error processing GIF 89.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193010>`` with iomode `r?`.
# Error processing GIF 498.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d350>`` with iomode `r?`.
# Error processing GIF 539.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d990>`` with iomode `r?`.
# Error processing GIF 411.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018db70>`` with iomode `r?`.
# Error processing GIF 715.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184c70>`` with iomode `r?`.
# Error processing GIF 455.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153380>`` with iomode `r?`.
# Error processing GIF 409.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 32.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3ba0>`` with iomode `r?`.
# Error processing GIF 474.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01934c0>`` with iomode `r?`.
# Error processing GIF 563.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192bb0>`` with iomode `r?`.
# Error processing GIF 381.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3970>`` with iomode `r?`.
# Error processing GIF 283.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 592.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e20>`` with iomode `r?`.
# Error processing GIF 674.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536a0>`` with iomode `r?`.
# Error processing GIF 363.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e0950>`` with iomode `r?`.
# Error processing GIF 181.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01904f0>`` with iomode `r?`.
# Error processing GIF 508.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cf380>`` with iomode `r?`.
# Error processing GIF 641.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce480>`` with iomode `r?`.
# Error processing GIF 607.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce0c0>`` with iomode `r?`.
# Error processing GIF 537.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167c40>`` with iomode `r?`.
# Error processing GIF 463.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190a90>`` with iomode `r?`.
# Error processing GIF 685.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192110>`` with iomode `r?`.
# Error processing GIF 975.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04367f0>`` with iomode `r?`.
# Error processing GIF 736.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165d50>`` with iomode `r?`.
# Error processing GIF 7.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164360>`` with iomode `r?`.
# Error processing GIF 230.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cf010>`` with iomode `r?`.
# Error processing GIF 267.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01849f0>`` with iomode `r?`.
# Error processing GIF 434.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce7a0>`` with iomode `r?`.
# Error processing GIF 123.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186520>`` with iomode `r?`.
# Error processing GIF 265.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191c10>`` with iomode `r?`.
# Error processing GIF 454.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc7c0>`` with iomode `r?`.
# Error processing GIF 218.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01910d0>`` with iomode `r?`.
# Error processing GIF 64.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018e480>`` with iomode `r?`.
# Error processing GIF 57.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 334.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b1a0>`` with iomode `r?`.
# Error processing GIF 863.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 171.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23b420>`` with iomode `r?`.
# Error processing GIF 243.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0812520>`` with iomode `r?`.
# Error processing GIF 849.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e70>`` with iomode `r?`.
# Error processing GIF 887.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152750>`` with iomode `r?`.
# Error processing GIF 11.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0153e20>`` with iomode `r?`.
# Error processing GIF 244.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01643b0>`` with iomode `r?`.
# Error processing GIF 732.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01644f0>`` with iomode `r?`.
# Error processing GIF 441.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 912.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0165210>`` with iomode `r?`.
# Error processing GIF 714.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186a70>`` with iomode `r?`.
# Error processing GIF 442.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191440>`` with iomode `r?`.
# Error processing GIF 860.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01902c0>`` with iomode `r?`.
# Error processing GIF 271.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166570>`` with iomode `r?`.
# Error processing GIF 717.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01673d0>`` with iomode `r?`.
# Error processing GIF 949.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167330>`` with iomode `r?`.
# Error processing GIF 651.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01655d0>`` with iomode `r?`.
# Error processing GIF 1009.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cc3b0>`` with iomode `r?`.
# Error processing GIF 809.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152890>`` with iomode `r?`.
# Error processing GIF 797.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018ebb0>`` with iomode `r?`.
# Error processing GIF 865.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d080>`` with iomode `r?`.
# Error processing GIF 692.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01652b0>`` with iomode `r?`.
# Error processing GIF 10.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018f240>`` with iomode `r?`.
# Error processing GIF 778.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018e2f0>`` with iomode `r?`.
# Error processing GIF 390.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186840>`` with iomode `r?`.
# Error processing GIF 961.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192fc0>`` with iomode `r?`.
# Error processing GIF 551.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193b50>`` with iomode `r?`.
# Error processing GIF 925.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e1440>`` with iomode `r?`.
# Error processing GIF 640.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3f10>`` with iomode `r?`.
# Error processing GIF 415.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01536f0>`` with iomode `r?`.
# Error processing GIF 60.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23b420>`` with iomode `r?`.
# Error processing GIF 683.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193d30>`` with iomode `r?`.
# Error processing GIF 599.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01911c0>`` with iomode `r?`.
# Error processing GIF 831.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190d60>`` with iomode `r?`.
# Error processing GIF 353.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d84f0>`` with iomode `r?`.
# Error processing GIF 272.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfd80>`` with iomode `r?`.
# ...
# Error processing GIF 697.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb239b20>`` with iomode `r?`.
# Error processing GIF 728.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0184180>`` with iomode `r?`.
# Error processing GIF 222.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186110>`` with iomode `r?`.
# Error processing GIF 986.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 349.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018eca0>`` with iomode `r?`.
# Error processing GIF 546.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191300>`` with iomode `r?`.
# Error processing GIF 947.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192980>`` with iomode `r?`.
# Error processing GIF 52.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b1da0>`` with iomode `r?`.
# Error processing GIF 286.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01531a0>`` with iomode `r?`.
# Error processing GIF 97.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0191990>`` with iomode `r?`.
# Error processing GIF 386.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01913f0>`` with iomode `r?`.
# Error processing GIF 836.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b04a0>`` with iomode `r?`.
# Error processing GIF 959.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018dc10>`` with iomode `r?`.
# Error processing GIF 223.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190fe0>`` with iomode `r?`.
# Error processing GIF 517.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193a60>`` with iomode `r?`.
# Error processing GIF 699.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194770>`` with iomode `r?`.
# Error processing GIF 939.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b16c0>`` with iomode `r?`.
# Error processing GIF 200.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dca40>`` with iomode `r?`.
# Error processing GIF 129.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195a80>`` with iomode `r?`.
# Error processing GIF 708.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dc130>`` with iomode `r?`.
# Error processing GIF 988.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01ddee0>`` with iomode `r?`.
# Error processing GIF 589.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dd030>`` with iomode `r?`.
# Error processing GIF 364.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05e3e20>`` with iomode `r?`.
# Error processing GIF 764.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060e020>`` with iomode `r?`.
# Error processing GIF 63.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b830>`` with iomode `r?`.
# Error processing GIF 964.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152de0>`` with iomode `r?`.
# Error processing GIF 995.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa02e0b30>`` with iomode `r?`.
# Error processing GIF 888.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b3bf0>`` with iomode `r?`.
# Error processing GIF 330.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01921b0>`` with iomode `r?`.
# Error processing GIF 77.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164090>`` with iomode `r?`.
# Error processing GIF 783.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018efc0>`` with iomode `r?`.
# Error processing GIF 159.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23bec0>`` with iomode `r?`.
# Error processing GIF 1008.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018e7f0>`` with iomode `r?`.
# Error processing GIF 751.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167d80>`` with iomode `r?`.
# Error processing GIF 440.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194770>`` with iomode `r?`.
# Error processing GIF 470.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0196520>`` with iomode `r?`.
# Error processing GIF 380.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0192e30>`` with iomode `r?`.
# Error processing GIF 822.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b26b0>`` with iomode `r?`.
# Error processing GIF 530.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 846.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b2fc0>`` with iomode `r?`.
# Error processing GIF 624.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195260>`` with iomode `r?`.
# Error processing GIF 458.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb239b20>`` with iomode `r?`.
# Error processing GIF 766.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b0310>`` with iomode `r?`.
# Error processing GIF 125.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dcd60>`` with iomode `r?`.
# Error processing GIF 990.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018dee0>`` with iomode `r?`.
# Error processing GIF 384.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfec0>`` with iomode `r?`.
# Error processing GIF 465.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b0cc0>`` with iomode `r?`.
# Error processing GIF 238.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195a80>`` with iomode `r?`.
# Error processing GIF 314.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dce50>`` with iomode `r?`.
# Error processing GIF 827.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054f920>`` with iomode `r?`.
# Error processing GIF 228.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b0cc0>`` with iomode `r?`.
# Error processing GIF 829.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b2930>`` with iomode `r?`.
# Error processing GIF 856.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0197ab0>`` with iomode `r?`.
# Error processing GIF 299.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194fe0>`` with iomode `r?`.
# Error processing GIF 1012.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa02e0b30>`` with iomode `r?`.
# Error processing GIF 588.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060e020>`` with iomode `r?`.
# Error processing GIF 419.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194e00>`` with iomode `r?`.
# Error processing GIF 252.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152930>`` with iomode `r?`.
# Error processing GIF 901.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d5d0>`` with iomode `r?`.
# Error processing GIF 37.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0185990>`` with iomode `r?`.
# Error processing GIF 575.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b34c0>`` with iomode `r?`.
# Error processing GIF 658.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b3790>`` with iomode `r?`.
# Error processing GIF 19.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d8310>`` with iomode `r?`.
# Error processing GIF 622.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cdad0>`` with iomode `r?`.
# Error processing GIF 309.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152de0>`` with iomode `r?`.
# Error processing GIF 8.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0190fe0>`` with iomode `r?`.
# Error processing GIF 199.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfdb23bfb0>`` with iomode `r?`.
# Error processing GIF 955.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194810>`` with iomode `r?`.
# Error processing GIF 300.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195990>`` with iomode `r?`.
# Error processing GIF 545.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01de2a0>`` with iomode `r?`.
# Error processing GIF 785.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01de160>`` with iomode `r?`.
# Error processing GIF 69.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dcae0>`` with iomode `r?`.
# Error processing GIF 506.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b3f10>`` with iomode `r?`.
# Error processing GIF 954.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01ddad0>`` with iomode `r?`.
# Error processing GIF 605.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01953f0>`` with iomode `r?`.
# Error processing GIF 491.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01de2f0>`` with iomode `r?`.
# Error processing GIF 672.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0196f20>`` with iomode `r?`.
# Error processing GIF 416.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa05d8040>`` with iomode `r?`.
# Error processing GIF 653.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152930>`` with iomode `r?`.
# Error processing GIF 274.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa09a15d0>`` with iomode `r?`.
# Error processing GIF 915.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068eb60>`` with iomode `r?`.
# Error processing GIF 461.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cfec0>`` with iomode `r?`.
# Error processing GIF 504.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0193c40>`` with iomode `r?`.
# Error processing GIF 31.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04ce5c0>`` with iomode `r?`.
# Error processing GIF 242.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018d5d0>`` with iomode `r?`.
# Error processing GIF 85.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa054c0e0>`` with iomode `r?`.
# Error processing GIF 322.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018dc60>`` with iomode `r?`.
# Error processing GIF 958.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b3740>`` with iomode `r?`.
# Error processing GIF 662.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b21b0>`` with iomode `r?`.
# Error processing GIF 88.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0196750>`` with iomode `r?`.
# Error processing GIF 376.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195120>`` with iomode `r?`.
# Error processing GIF 739.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b38d0>`` with iomode `r?`.
# Error processing GIF 479.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0186250>`` with iomode `r?`.
# Error processing GIF 511.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dc5e0>`` with iomode `r?`.
# Error processing GIF 713.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01de930>`` with iomode `r?`.
# Error processing GIF 861.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01976f0>`` with iomode `r?`.
# Error processing GIF 582.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dd6c0>`` with iomode `r?`.
# Error processing GIF 719.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01947c0>`` with iomode `r?`.
# Error processing GIF 723.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164ae0>`` with iomode `r?`.
# Error processing GIF 370.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dcd10>`` with iomode `r?`.
# Error processing GIF 697.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195990>`` with iomode `r?`.
# Error processing GIF 728.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0194c20>`` with iomode `r?`.
# Error processing GIF 222.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018dc10>`` with iomode `r?`.
# Error processing GIF 986.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dea70>`` with iomode `r?`.
# Error processing GIF 349.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dcf90>`` with iomode `r?`.
# Error processing GIF 546.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060c3b0>`` with iomode `r?`.
# Error processing GIF 947.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa068eb60>`` with iomode `r?`.
# Error processing GIF 52.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa060e020>`` with iomode `r?`.
# Error processing GIF 286.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b3dd0>`` with iomode `r?`.
# Error processing GIF 97.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa077b830>`` with iomode `r?`.
# Error processing GIF 386.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0167880>`` with iomode `r?`.
# Error processing GIF 836.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b2b10>`` with iomode `r?`.
# Error processing GIF 959.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018f9c0>`` with iomode `r?`.
# Error processing GIF 223.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018f010>`` with iomode `r?`.
# Error processing GIF 517.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa018c950>`` with iomode `r?`.
# Error processing GIF 699.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01919e0>`` with iomode `r?`.
# Error processing GIF 939.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01932e0>`` with iomode `r?`.
# Error processing GIF 200.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa04cebb0>`` with iomode `r?`.
# Error processing GIF 129.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0164090>`` with iomode `r?`.
# Error processing GIF 708.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166b60>`` with iomode `r?`.
# Error processing GIF 988.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0166d40>`` with iomode `r?`.
# Error processing GIF 589.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01531a0>`` with iomode `r?`.
# Error processing GIF 364.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01b10d0>`` with iomode `r?`.
# Error processing GIF 764.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dccc0>`` with iomode `r?`.
# Error processing GIF 63.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01ddad0>`` with iomode `r?`.
# Error processing GIF 964.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dc630>`` with iomode `r?`.
# Error processing GIF 995.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0152890>`` with iomode `r?`.
# Error processing GIF 888.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01de160>`` with iomode `r?`.
# Error processing GIF 330.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa0195a80>`` with iomode `r?`.
# Error processing GIF 77.gif: Could not find a backend to open `<_io.BytesIO object at 0x7acfa01dfce0>`` with iomode `r?`.
